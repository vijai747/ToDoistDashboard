# %%
# %%bash
#
# head md_traffic.json
# Out:
# {
#   "meta" : {
#     "view" : {
#       "id" : "4mse-ku6q",
#       "name" : "Traffic Violations",
#       "averageRating" : 0,
#       "category" : "Public Safety",
#       "createdAt" : 1403103517,
#       "description" : "This dataset contains traffic violation information from all electronic traffic violations issued in the County.  Any information that can be used to uniquely identify the vehicle, the vehicle owner or the officer issuing the violation will not be published.\r\n\r\nUpdate Frequency:  Daily",
#       "displayType" : "table",

# %%
# %%bash
#
# grep -E '^ {2}"' md_traffic.json
# Out:
#   "meta" : {
#   "data" : [ [ 2118167, "EE8BC302-660F-48C4-B422-17427ECE821F", 2118167, 1482239054, "498050", 1482239054, "498050", null, "2013-09-24T00:00:00", "17:11:00", "MCP", "3rd district, Silver Spring", "DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION", "8804 FLOWER AVE", null, null, "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "MD", "02 - Automobile", "2008", "FORD", "4S", "BLACK", "Citation", "13-401(h)", "Transportation Article", "No", "BLACK", "M", "TAKOMA PARK", "MD", "MD", "A - Marked Patrol", [ null, null, null, null, null ] ]

# %%
# %%bash
#
# grep -E '^ {2,6}"' md_traffic.json
# Out:
#   "meta" : {
#     "view" : {
#       "id" : "4mse-ku6q",
#       "name" : "Traffic Violations",
#       "averageRating" : 0,
#       "category" : "Public Safety",
#       "createdAt" : 1403103517,
#       "description" : "This dataset contains traffic violation information from all electronic traffic violations issued in the County.  Any information that can be used to uniquely identify the vehicle, the vehicle owner or the officer issuing the violation will not be published.\r\n\r\nUpdate Frequency:  Daily",
#       "displayType" : "table",
#       "downloadCount" : 78309,
#       "hideFromCatalog" : false,
#       "hideFromDataJson" : false,
#       "iconUrl" : "fileId:r41tDc239M1FL75LFwXFKzFCWqr8mzMeMTYXiA24USM",
#       "indexUpdatedAt" : 1505813492,
#       "newBackend" : false,
#       "numberOfComments" : 0,
#       "oid" : 8890705,
#       "provenance" : "official",
#       "publicationAppendEnabled" : false,
#       "publicationDate" : 1411040702,
#       "publicationGroup" : 1620779,
#       "publicationStage" : "published",
#       "rowClass" : "",
#       "rowsUpdatedAt" : 1505813341,
#       "rowsUpdatedBy" : "ajn4-zy65",
#       "tableId" : 1722160,
#       "totalTimesRated" : 0,
#       "viewCount" : 22128,
#       "viewLastModified" : 1494270268,
#       "viewType" : "tabular",
#       "columns" : [ {
#       "disabledFeatureFlags" : [ "allow_comments" ],
#       "grants" : [ {
#       "metadata" : {
#       "owner" : {
#       "query" : {
#       "rights" : [ "read" ],
#       "tableAuthor" : {
#       "tags" : [ "traffic", "stop", "violations", "electronic issued." ],
#       "flags" : [ "default", "restorable", "restorePossibleForType" ]
#   "data" : [ [ 2118167, "EE8BC302-660F-48C4-B422-17427ECE821F", 2118167, 1482239054, "498050", 1482239054, "498050", null, "2013-09-24T00:00:00", "17:11:00", "MCP", "3rd district, Silver Spring", "DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION", "8804 FLOWER AVE", null, null, "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "MD", "02 - Automobile", "2008", "FORD", "4S", "BLACK", "Citation", "13-401(h)", "Transportation Article", "No", "BLACK", "M", "TAKOMA PARK", "MD", "MD", "A - Marked Patrol", [ null, null, null, null, null ] ]

# %%
import ijson

filename = "md_traffic.json"
with open(filename, 'r') as f:
    objects = ijson.items(f, 'meta.view.columns.item')
    columns = list(objects)

# %%
print (type(columns))
print(columns[0])
# Out:
# <class 'list'>
# {'id': -1, 'name': 'sid', 'dataTypeName': 'meta_data', 'fieldName': ':sid', 'position': 0, 'renderTypeName': 'meta_data', 'format': {}, 'flags': ['hidden']}

# %%
column_names = [col["fieldName"] for col in columns]
column_names
# Out:
# [':sid',
#  ':id',
#  ':position',
#  ':created_at',
#  ':created_meta',
#  ':updated_at',
#  ':updated_meta',
#  ':meta',
#  'date_of_stop',
#  'time_of_stop',
#  'agency',
#  'subagency',
#  'description',
#  'location',
#  'latitude',
#  'longitude',
#  'accident',
#  'belts',
#  'personal_injury',
#  'property_damage',
#  'fatal',
#  'commercial_license',
#  'hazmat',
#  'commercial_vehicle',
#  'alcohol',
#  'work_zone',
#  'state',
#  'vehicle_type',
#  'year',
#  'make',
#  'model',
#  'color',
#  'violation_type',
#  'charge',
#  'article',
#  'contributed_to_accident',
#  'race',
#  'gender',
#  'driver_city',
#  'driver_state',
#  'dl_state',
#  'arrest_type',
#  'geolocation']

# %%
good_columns = [
    "date_of_stop", 
    "time_of_stop", 
    "agency", 
    "subagency",
    "description",
    "location", 
    "latitude", 
    "longitude", 
    "vehicle_type", 
    "year", 
    "make", 
    "model", 
    "color", 
    "violation_type",
    "race", 
    "gender", 
    "driver_state", 
    "driver_city", 
    "dl_state",
    "arrest_type"
]

data = []
with open(filename, 'r') as f:
    objects = ijson.items(f, 'data.item')
    for row in objects:
        selected_row = []
        for item in good_columns:
            selected_row.append(row[column_names.index(item)])
        data.append(selected_row)

# %%
data[0]
# Out:
# ['2013-09-24T00:00:00',
#  '17:11:00',
#  'MCP',
#  '3rd district, Silver Spring',
#  'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#  '8804 FLOWER AVE',
#  None,
#  None,
#  '02 - Automobile',
#  '2008',
#  'FORD',
#  '4S',
#  'BLACK',
#  'Citation',
#  'BLACK',
#  'M',
#  'MD',
#  'TAKOMA PARK',
#  'MD',
#  'A - Marked Patrol']

# %%
import pandas as pd

stops = pd.DataFrame(data, columns=good_columns)

# %%
stops["color"].value_counts()
# Out:
# BLACK          230899
# SILVER         212699
# WHITE          176279
# GRAY           124957
# RED             91962
# BLUE            85507
# GREEN           46005
# GOLD            37697
# TAN             25057
# BLUE, DARK      24566
# MAROON          20421
# BLUE, LIGHT     15745
# BEIGE           13843
# GREEN, DK       13407
# N/A             13401
# GREEN, LGT       6817
# BROWN            5515
# YELLOW           4483
# ORANGE           4057
# BRONZE           2727
# PURPLE           2299
# MULTICOLOR        949
# CREAM             775
# COPPER            374
# PINK              177
# CHROME             24
# CAMOUFLAGE         23
# Name: color, dtype: int64

# %%
stops["arrest_type"].value_counts()
# Out:
# A - Marked Patrol                         949376
# Q - Marked Laser                          115784
# B - Unmarked Patrol                        37411
# S - License Plate Recognition              13134
# O - Foot Patrol                            11942
# L - Motorcycle                             11026
# E - Marked Stationary Radar                 7241
# R - Unmarked Laser                          5352
# G - Marked Moving Radar (Stationary)        4711
# I - Marked Moving Radar (Moving)            1714
# M - Marked (Off-Duty)                       1697
# F - Unmarked Stationary Radar                802
# H - Unmarked Moving Radar (Stationary)       683
# C - Marked VASCAR                            420
# J - Unmarked Moving Radar (Moving)           364
# P - Mounted Patrol                           290
# D - Unmarked VASCAR                          242
# N - Unmarked (Off-Duty)                      169
# K - Aircraft Assist                           53
# Name: arrest_type, dtype: int64

# %%
import numpy as np

def parse_float(x):
    try:
        x = float(x)
    except Exception:
        x = 0
    return x
stops["longitude"] = stops["longitude"].apply(parse_float)
stops["latitude"] = stops["latitude"].apply(parse_float)

# %%
import datetime
def parse_full_date(row):
    date = datetime.datetime.strptime(row["date_of_stop"], "%Y-%m-%dT%H:%M:%S")
    time = row["time_of_stop"].split(":")
    date = date.replace(hour=int(time[0]), minute = int(time[1]), second = int(time[2]))
    return date

stops["date"] = stops.apply(parse_full_date, axis=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.hist(stops["date"].dt.weekday, bins=6)
# Out:
# (array([ 157772.,  199612.,  188294.,  179334.,  182506.,  254893.]),
#  array([ 0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  <a list of 6 Patch objects>)

# %%
plt.hist(stops["date"].dt.hour, bins=24)
# Out:
# (array([ 63606.,  51973.,  39826.,  26336.,  16076.,  10746.,  17248.,
#          41199.,  62571.,  58021.,  59123.,  49399.,  45434.,  46178.,
#          48325.,  40913.,  55587.,  58113.,  45695.,  40655.,  45008.,
#          64035.,  89218.,  87126.]),
#  array([  0.        ,   0.95833333,   1.91666667,   2.875     ,
#           3.83333333,   4.79166667,   5.75      ,   6.70833333,
#           7.66666667,   8.625     ,   9.58333333,  10.54166667,
#          11.5       ,  12.45833333,  13.41666667,  14.375     ,
#          15.33333333,  16.29166667,  17.25      ,  18.20833333,
#          19.16666667,  20.125     ,  21.08333333,  22.04166667,  23.        ]),
#  <a list of 24 Patch objects>)

# %%
last_year = stops[stops["date"] > datetime.datetime(year=2015, month=2, day=18)]

# %%
morning_rush = last_year[(last_year["date"].dt.weekday < 5) & (last_year["date"].dt.hour > 5) & (last_year["date"].dt.hour < 10)]
print(morning_rush.shape)
last_year.shape
# Out:
# (72375, 21)
# (567899, 21)

# %%
import folium
from folium import plugins

stops_map = folium.Map(location=[39.0836, -77.1483], zoom_start=11)
marker_cluster = plugins.MarkerCluster().add_to(stops_map)
for name, row in morning_rush.iloc[:200].iterrows():
    #folium.Marker([row["longitude"], row["latitude"]], popup=row["description"]).add_to(marker_cluster)
    folium.Marker([row["latitude"], row["longitude"]], popup=row["description"]).add_to(marker_cluster)
#stops_map.create_map('stops.html')
stops_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stops_heatmap = folium.Map(location=[39.0836, -77.1483], zoom_start=11)
stops_heatmap.add_child(plugins.HeatMap([[row["latitude"], row["longitude"]] for name, row in morning_rush.iloc[:200].iterrows()]))
#stops_heatmap.save("heatmap.html")
stops_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
